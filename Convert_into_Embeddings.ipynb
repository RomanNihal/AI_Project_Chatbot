# %%
from sentence_transformers import SentenceTransformer
import numpy as np
import json

# %%
with open("basmah_faq_knowledge_base.json", "r") as f:
  faqs = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-05f2b7ee886d> in <cell line: 0>()
# ----> 1 with open("basmah_faq_knowledge_base.json", "r") as f:
#       2   faqs = json.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'basmah_faq_knowledge_base.json'

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
faq_questions = [faq['question'] for faq in faqs]
faq_embeddings = model.encode(faq_questions)

# %%
np.save("faq_embeddings.npy", faq_embeddings)
